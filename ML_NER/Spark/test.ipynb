# %%
import pyspark

# %%
import pandas as pd
pd.read_csv('euro2012.csv')
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...
